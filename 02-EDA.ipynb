# %% [markdown]
# # Hospital Treatment Cost Prediction System
# ## Exploratory Data Analysis(EDA)

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Import Cleaned Dataset

# %%
df = pd.read_csv("cleaned_data.csv")

# %% [markdown]
# ### Display Top 5 Records

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# ### Dataset Shape

# %%
df.shape
# Out:
# (1337, 7)

# %% [markdown]
# ### Age Distribution

# %%
plt.figure(figsize=(8,5))
sns.histplot(df["age"], bins=20, kde=True)
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ### Findings
# - Most patients are between 20 and 50 years of age
# - Very few patients are above 60 years

# %% [markdown]
# ### Gender Distribution

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="sex", data=df)
plt.title("Gender Distribution")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ### Findings
# - Male and female records are almost equally distributed

# %% [markdown]
# ### Age Distribution

# %%
plt.figure(figsize=(8,5))
sns.histplot(df["bmi"], bins=20, kde=True)
plt.title("BMI Distribution")
plt.xlabel("BMI")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ### Findings
# - Most BMI values lie between 25 & 35

# %% [markdown]
# ### Children Distribution

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="children", data=df)
plt.title("Children Distribution")
plt.xlabel("Number of Children")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ### Findings
# - Most people have 0 children in the dataset
# - Very few people have 3 or more children
# - The distribution is right-skewed

# %% [markdown]
# ### Smoker Distribution

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="smoker", data=df)
plt.title("Smoker Distribution")
plt.xlabel("Smoker")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ### Findings
# Most people are non-smokers in the dataset

# %% [markdown]
# ### Region Distribution

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="region", data=df)
plt.title("Region Distribution")
plt.xlabel("Region")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ### Findings
# - Dataset is fairly distributed across regions

# %% [markdown]
# ## Relationship Analysis

# %% [markdown]
# #### Age vs Charges

# %%
plt.figure(figsize=(6,4))
sns.scatterplot(x="age", y = "charges", data=df)
plt.title("Age vs Charges")
plt.xlabel("Age")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ### Findings
# - Charges increase with age

# %% [markdown]
# #### BMI vs Charges

# %%
plt.figure(figsize=(6,4))
sns.scatterplot(x="bmi", y = "charges", data=df)
plt.title("BMI vs Charges")
plt.xlabel("BMI")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ### Findings
# - Higher BMI leads to higher charges

# %% [markdown]
# #### Smoker vs Charges

# %%
plt.figure(figsize=(6,4))
sns.scatterplot(x="smoker", y = "charges", data=df)
plt.title("Smoker vs Charges")
plt.xlabel("Smoker")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ### Findings
# - Smokers have much higher charges than non-smokers

# %% [markdown]
# #### Heatmap

# %%
plt.figure(figsize=(6,4))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# #### Findings
# - Age, BMI and smoker have strong relation with charges

# %% [markdown]
# #### Business Insights

# %% [markdown]
# - Smoking is the strongest factor affecting charges
# - Age and BMI also increase insurance cost
# - Gender and region have little impact
# - Most users are non-smokers with normal BMI
